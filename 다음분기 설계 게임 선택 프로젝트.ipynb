# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/vgames2.csv')
df
# Out:
#       Unnamed: 0  ... Other_Sales
# 0              1  ...        0.00
# 1              2  ...        0.01
# 2              3  ...        0.00
# 3              4  ...        0.00
# 4              5  ...        0.04
# ...          ...  ...         ...
# 16593      16594  ...        0.01
# 16594      16595  ...        0.00
# 16595      16596  ...        0.13
# 16596      16597  ...        0.03
# 16597      16598  ...        0.01
#
# [16598 rows x 10 columns]

# %%
df['Year'] = df['Year'].fillna(0)

# %%
df['Year'] = df['Year'].astype(int)

# %%
def year(string):
    if string <= 20:
        string += 2000
        return string
    elif string >=20 and string <= 100:
        string += 1900
        return string
    else:
        return string

# %%
df['Year'] = df['Year'].apply(year)

# %%
t1 = df.iloc[:,[4,6,7,8,9]]
t1
# Out:
#            Genre  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0         Action      0.04      0.00      0.00         0.00
# 1         Action      0.17      0.00      0.00         0.01
# 2      Adventure      0.00      0.00      0.02         0.00
# 3           Misc      0.04      0.00      0.00         0.00
# 4       Platform      0.12      0.09      0.00         0.04
# ...          ...       ...       ...       ...          ...
# 16593   Platform      0.15      0.04      0.00         0.01
# 16594     Action      0.01      0.00      0.00         0.00
# 16595     Sports      0.44      0.19      0.03         0.13
# 16596     Action      0.05      0.05      0.25         0.03
# 16597   Fighting      0.00      0.00      0.16         0.01
#
# [16598 rows x 5 columns]

# %%
df3 = t1.groupby(['Genre']).sum()
df3
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Genre
# Action         874.810   522.160    157.90       186.45
# Adventure      105.660    64.170     51.83        16.81
# Fighting       223.200   101.220     87.34        36.64
# Misc           407.960   212.360    105.27        74.04
# Platform       446.440   201.052    130.65        51.53
# Puzzle         123.350    50.730     56.87        12.52
# Racing         357.190   237.100     56.40        77.10
# Role-Playing   319.540   183.580    344.95        56.96
# Shooter        581.920   313.050     38.28       102.65
# Simulation     182.960   113.350     63.70        31.48
# Sports         679.071   376.480    135.37       134.67
# Strategy        68.700    45.320     49.46        11.36

# %%
t2 = df.iloc[:,[3,4,6,7,8,9]]
t2
# Out:
#        Year      Genre  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0      2008     Action      0.04      0.00      0.00         0.00
# 1      2009     Action      0.17      0.00      0.00         0.01
# 2      2010  Adventure      0.00      0.00      0.02         0.00
# 3      2010       Misc      0.04      0.00      0.00         0.00
# 4      2010   Platform      0.12      0.09      0.00         0.04
# ...     ...        ...       ...       ...       ...          ...
# 16593  2006   Platform      0.15      0.04      0.00         0.01
# 16594  2005     Action      0.01      0.00      0.00         0.00
# 16595  2015     Sports      0.44      0.19      0.03         0.13
# 16596  2013     Action      0.05      0.05      0.25         0.03
# 16597  1996   Fighting      0.00      0.00      0.16         0.01
#
# [16598 rows x 6 columns]

# %%
t2['Year'] = t2['Year'].astype(str)

t5 = t2.replace(['1980','1981','1982','1983','1984'],'1980-1984')
t5 = t5.replace(['1985','1986','1987','1988','1989'],'1985-1989')
t5 = t5.replace(['1990','1991','1992','1993','1994'],'1990-1994')
t5 = t5.replace(['1995','1996','1997','1998','1999'],'1995-1999')
t5 = t5.replace(['2000','2001','2002','2003','2004'],'2000-2004')
t5 = t5.replace(['2005','2006','2007','2008','2009'],'2005-2009')
t5 = t5.replace(['2010','2011','2012','2013','2014'],'2010-2014')
t5 = t5.replace(['2015','2016','2017','2018','2020'],'2015-2020')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
total = t2['NA_Sales']+t2['EU_Sales']+t2['JP_Sales']+t2['Other_Sales']
t2['total'] = total
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
total1 = t5['NA_Sales']+t5['EU_Sales']+t5['JP_Sales']+t5['Other_Sales']
t5['total'] = total1
t5
# Out:
#             Year      Genre  NA_Sales  EU_Sales  JP_Sales  Other_Sales  total
# 0      2005-2009     Action      0.04      0.00      0.00         0.00   0.04
# 1      2005-2009     Action      0.17      0.00      0.00         0.01   0.18
# 2      2010-2014  Adventure      0.00      0.00      0.02         0.00   0.02
# 3      2010-2014       Misc      0.04      0.00      0.00         0.00   0.04
# 4      2010-2014   Platform      0.12      0.09      0.00         0.04   0.25
# ...          ...        ...       ...       ...       ...          ...    ...
# 16593  2005-2009   Platform      0.15      0.04      0.00         0.01   0.20
# 16594  2005-2009     Action      0.01      0.00      0.00         0.00   0.01
# 16595  2015-2020     Sports      0.44      0.19      0.03         0.13   0.79
# 16596  2010-2014     Action      0.05      0.05      0.25         0.03   0.38
# 16597  1995-1999   Fighting      0.00      0.00      0.16         0.01   0.17
#
# [16598 rows x 7 columns]

# %%
yyy = t5['total'].groupby([t5['Year'],t5['Genre']]).sum().unstack().fillna(0)
yyy = pd.DataFrame(yyy)
yyy
# Out:
# Genre      Action  Adventure  Fighting  ...  Simulation   Sports  Strategy
# Year                                    ...
# 1980-1984   26.34       0.40      0.77  ...        0.44   11.210      0.00
# 1985-1989   24.76       4.38      6.47  ...        0.07   20.570      0.00
# 1990-1994   20.35      18.29     32.84  ...        8.33   19.060      5.68
# 1995-1999  118.80      26.51     90.67  ...       43.71  127.410     51.83
# 2000-2004  349.65      37.99    108.69  ...       67.86  296.790     38.36
# 2005-2009  531.78      89.95    127.43  ...      199.81  527.720     43.16
# 2010-2014  581.53      51.01     69.90  ...       64.98  266.711     33.47
# 2015-2020   88.11       9.82     11.63  ...        6.29   56.120      2.34
#
# [8 rows x 12 columns]

# %%
t6 = t5.groupby(['Year']).sum()
t6
# Out:
#            NA_Sales  EU_Sales  JP_Sales  Other_Sales     total
# Year
# 1980-1984   111.950     7.180     22.37         1.59   143.090
# 1985-1989   123.710    24.020     80.12         5.54   233.390
# 1990-1994   115.360    42.820    117.89         6.88   282.950
# 1995-1999   460.750   240.050    254.44        40.54   995.780
# 2000-2004   960.360   493.640    206.96       143.70  1804.540
# 2005-2009  1508.070   787.670    310.37       329.77  2935.880
# 2010-2014   985.461   713.842    251.28       231.95  2182.533
# 2015-2020   125.750   124.470     47.47        37.78   335.470

# %%
t5.groupby(['Year','Genre']).sum()
# Out:
#                         NA_Sales  EU_Sales  JP_Sales  Other_Sales  total
# Year      Genre
# 1980-1984 Action           23.72      1.57      0.83         0.22  26.34
#           Adventure         0.38      0.02      0.00         0.00   0.40
#           Fighting          0.72      0.04      0.00         0.01   0.77
#           Misc              3.35      0.20      3.58         0.03   7.16
#           Platform         13.96      1.08      4.31         0.22  19.57
# ...                          ...       ...       ...          ...    ...
# 2015-2020 Role-Playing     14.74     13.81     10.38         4.29  43.22
#           Shooter          38.23     31.93      3.30        10.83  84.29
#           Simulation        1.40      2.60      1.88         0.41   6.29
#           Sports           23.03     24.05      1.50         7.54  56.12
#           Strategy          0.68      1.30      0.20         0.16   2.34
#
# [93 rows x 5 columns]

# %%
t2['Year'] = t2['Year'].astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df4 = t2.groupby(['Year','Genre']).sum()
df4
# Out:
#                    NA_Sales  EU_Sales  JP_Sales  Other_Sales  total
# Year Genre
# 1980 Action            0.32      0.02      0.00         0.00   0.34
#      Fighting          0.72      0.04      0.00         0.01   0.77
#      Misc              2.53      0.15      0.00         0.02   2.70
#      Shooter           6.56      0.43      0.00         0.08   7.07
# 1981 Action           13.86      0.81      0.00         0.12  14.79
# ...                     ...       ...       ...          ...    ...
# 2016 Sports            4.57      7.36      0.78         1.92  14.63
#      Strategy          0.11      0.32      0.05         0.04   0.52
# 2017 Action            0.00      0.00      0.01         0.00   0.01
#      Role-Playing      0.00      0.00      0.04         0.00   0.04
# 2020 Simulation        0.27      0.00      0.00         0.02   0.29
#
# [388 rows x 5 columns]

# %%
df5 = t2.groupby(['Year']).sum()

# %%
Platform = df['Platform']
t5['Platform'] = Platform

# %%
Platform = df['Platform']
t2['Platform'] = Platform
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
t8 = t5.groupby(['Platform']).sum()

# %%
from scipy import stats
from scipy.stats import f_oneway

# %%
ddf3 = df3.T

# %%
ddf3['총합'] = (ddf3['Action']+ddf3['Adventure']+ddf3['Fighting']+ddf3['Misc']+ddf3['Platform']+ddf3['Puzzle']+ddf3['Racing']+ddf3['Role-Playing']+ddf3['Shooter']+ddf3['Simulation']+ddf3['Sports']+ddf3['Strategy'])

# %%
ddf4 = ddf3[['총합']]
ddf4
# Out:
# Genre              총합
# NA_Sales     4370.801
# EU_Sales     2420.572
# JP_Sales     1278.020
# Other_Sales   792.210

# %% [markdown]
# 각 대륙별 게임 전체판매량을 확인한 결과 지역별 차이가 확연함을 알 수 있다

# %%
# 각 지역 장르별 판매도에 관한 ANOVA분석

g1 = df['NA_Sales']
g2 = df['EU_Sales']
g3 = df['JP_Sales']
g4 = df['Other_Sales'].fillna(0)

f_oneway(g1, g2, g3)
# Out:
# F_onewayResult(statistic=436.5740554594792, pvalue=1.1004393857903824e-188)

# %% [markdown]
# 판매량을 통하여 분석해본 결과 지역별에 따라서 장르 선호 차이가 있다는 결론이 나왔다.

# %%
# 각 장르별 지역판매량

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns

plt.rcParams['figure.figsize'] = [28, 12]
sns.lineplot(data = df3,  dashes = False);

# %% [markdown]
# 일본을 제외한 각 지역은 각 지역별 판매수 차이가 크지만 선호, 비선호 장르가 대부분 비슷한 것을 볼수있다. 특히 액션, 스포츠, 슈팅 게임이 대표적으로 강세를 보이며 어드벤쳐, 퍼즐, 시뮬레이션, 전략시뮬레이션 약세인것을 볼수있다.
# 이에반해 일본의 경우는 액션장르가 다른국가에 전체 판매량은 저조하나 일본내 다른 장르와 비교시 강세이며 롤플레잉 장르가 두드러지게 강세를 보이고 레이싱과 슈팅이 다른 지역과 비교해서 낮은 선호도를 보이고 전략시뮬레이션또한 약세이나  두드러지게 뛰어난 성적을 보이는 롤플레잉 게임을 제외하고는 대부분 크지않은 차이를 보이고있다.

# %%
# 각 지역별 년도에 따른 판매량

plt.rcParams['figure.figsize'] = [20, 8]
sns.lineplot(data = df5,  dashes = False);

# %%
plt.rcParams['figure.figsize'] = [20, 8]
sns.lineplot(data = t6,  dashes = False);

# %%
t6.plot.bar()

# %%
t6
# Out:
#            NA_Sales  EU_Sales  JP_Sales  Other_Sales     total
# Year
# 1980-1984   111.950     7.180     22.37         1.59   143.090
# 1985-1989   123.710    24.020     80.12         5.54   233.390
# 1990-1994   115.360    42.820    117.89         6.88   282.950
# 1995-1999   460.750   240.050    254.44        40.54   995.780
# 2000-2004   960.360   493.640    206.96       143.70  1804.540
# 2005-2009  1508.070   787.670    310.37       329.77  2935.880
# 2010-2014   985.461   713.842    251.28       231.95  2182.533
# 2015-2020   125.750   124.470     47.47        37.78   335.470

# %% [markdown]
# 각 지역별 년도별에 따른 게임 총 판매량을 시각화 해본 그래프입니다.
# 초창기 아직 게임이 제대로 보급되지않은 1980-1994년까지는 미미한 판매량을 보이다 1995-2009년까지 총 판매량이 폭증하는 추세를 보이는것을 알 수 있습니다.
# 그리고 2005-2009년 판매량이 피크를 찍고난후 서서히 판매량이 감소하기 시작해 현재는 피크때에 비하여 극소량만이 판매되는것을 확인 가능합니다.
#
# 이 현상은 어디서나 가볍게 게임을 할 수 있다는 장점으로 인기를 끌며 유저들을 흡수하여 급성장중인 모바일게임과 유명한 대부분의 게임들이 pc에도 게임을 이식하기 시작하며 게임기를 구매하기보다는 STEAM등을 이용하여 pc로 게임을 즐기는 유저들이 많아지며 일어난 트렌드 변화에 따른 현상이라고 생각합니다.

# %% [markdown]
# ![모바일게임 그래프.jpg](data:image/jpeg;base64,...)

# %%
# 년도별 게임장르 판매량

plt.rcParams['figure.figsize'] = [20, 8]
sns.lineplot(data = yyy,  dashes = False);

# %%
yyy.plot.bar()

# %%
yyy
# Out:
# Genre      Action  Adventure  Fighting  ...  Simulation   Sports  Strategy
# Year                                    ...
# 1980-1984   26.34       0.40      0.77  ...        0.44   11.210      0.00
# 1985-1989   24.76       4.38      6.47  ...        0.07   20.570      0.00
# 1990-1994   20.35      18.29     32.84  ...        8.33   19.060      5.68
# 1995-1999  118.80      26.51     90.67  ...       43.71  127.410     51.83
# 2000-2004  349.65      37.99    108.69  ...       67.86  296.790     38.36
# 2005-2009  531.78      89.95    127.43  ...      199.81  527.720     43.16
# 2010-2014  581.53      51.01     69.90  ...       64.98  266.711     33.47
# 2015-2020   88.11       9.82     11.63  ...        6.29   56.120      2.34
#
# [8 rows x 12 columns]

# %% [markdown]
# 이번에는 각 시기별 장르 트렌드 변화에 대하여 알아보겠다.
# 1980년에서 1984년 까지는 Shooter가
# 1985년부터 1994년 까지는 Platfrom이
# 1995년부터 1999년 까지는 Sports가
# 2000년부터 2020년인 현재 까지는 Action이 가장 인기가 있었다.

# %%
plt.rcParams['figure.figsize'] = [20, 8]
sns.lineplot(data = t8,  dashes = False);

# %%
t8
# Out:
#           NA_Sales  EU_Sales  JP_Sales  Other_Sales     total
# Platform
# 3DO          0.000     0.000      0.10         0.00     0.100
# 3DS         78.870    58.520     97.35        12.63   247.370
# DC           5.430     1.690      8.56         0.27    15.950
# DS         390.710   194.650    175.57        60.53   821.460
# GB         114.320    47.820     85.12         8.20   255.460
# GBA        278.140    80.720     47.33         8.64   414.830
# GC         133.460    38.710     21.58         5.18   198.930
# GEN         19.270     5.520      2.67         0.89    28.350
# GG           0.000     0.000      0.04         0.00     0.040
# N64        139.020    41.060     34.22         4.38   218.680
# NES        125.940    21.150     98.65         5.31   251.050
# NG           0.000     0.000      1.44         0.00     1.440
# PC          93.280   139.680      0.17        24.86   257.990
# PCFX         0.000     0.000      0.03         0.00     0.030
# ...

# %%
yyy1 = t2['total'].groupby([t2['Year'],t2['Platform']]).sum().unstack().fillna(0)
yyy1 = pd.DataFrame(yyy1)

# %%
yyy1= yyy1[['PS4','XOne','3DS','WiiU',]]

# %%
yyy1 = yyy1[30:37]

# %%
plt.rcParams['figure.figsize'] = [20, 8]
sns.lineplot(data = yyy1,  dashes = False);

# %% [markdown]
# 이전 기종을 데이터로 넣는건 무의미하다고 판단하여 현재 없어진 플랫폼이나 이전 버전은 삭제하고 판매되는 기종만을 넣어본결과 PS,닌텐도,XBOX순으로 팔리는걸 확인 가능했습니다.

# %%
# 출고량이 높은 게임에 대한 분석

# %%
x1 = df.iloc[:,[1,6,7,8,9]]

total2 = x1['NA_Sales']+x1['EU_Sales']+x1['JP_Sales']+x1['Other_Sales']

x1['total'] = total2
x2 = x1.iloc[:,[0,5]]
x2 = x2.sort_values(by=['total'], axis=0, ascending=False)

x2 = x2[0:10]
x2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#                             Name  total
# 2908                  Wii Sports  82.74
# 4199           Super Mario Bros.  40.24
# 12579             Mario Kart Wii  35.83
# 3352           Wii Sports Resort  33.00
# 7829    Pokemon Red/Pokemon Blue  31.38
# 1203                      Tetris  30.26
# 6937       New Super Mario Bros.  30.01
# 3014                    Wii Play  29.01
# 16531  New Super Mario Bros. Wii  28.61
# 10488                  Duck Hunt  28.31

# %%
x3 = x1.iloc[:,[0,1]]
x3 = x3.sort_values(by=['NA_Sales'], axis=0, ascending=False)

x3 = x3[0:10]
x3
# Out:
#                             Name  NA_Sales
# 2908                  Wii Sports     41.49
# 4199           Super Mario Bros.     29.08
# 10488                  Duck Hunt     26.93
# 1203                      Tetris     23.20
# 12579             Mario Kart Wii     15.85
# 3352           Wii Sports Resort     15.75
# 4343          Kinect Adventures!     14.97
# 16531  New Super Mario Bros. Wii     14.59
# 3014                    Wii Play     14.03
# 13111          Super Mario World     12.78

# %%
x4 = x1.iloc[:,[0,2]]
x4 = x4.sort_values(by=['EU_Sales'], axis=0, ascending=False)

x4 = x4[0:10]
x4
# Out:
#                                                Name  EU_Sales
# 2908                                     Wii Sports     29.02
# 12579                                Mario Kart Wii     12.88
# 3352                              Wii Sports Resort     11.01
# 11137                                    Nintendogs     11.00
# 3483                             Grand Theft Auto V      9.27
# 13229  Brain Age: Train Your Brain in Minutes a Day      9.26
# 6937                          New Super Mario Bros.      9.23
# 3014                                       Wii Play      9.20
# 7829                       Pokemon Red/Pokemon Blue      8.89
# 10899                                  Wii Fit Plus      8.59

# %%
x5 = x1.iloc[:,[0,3]]
x5 = x5.sort_values(by=['JP_Sales'], axis=0, ascending=False)

x5 = x5[0:10]
x5
# Out:
#                                               Name  JP_Sales
# 7829                      Pokemon Red/Pokemon Blue     10.22
# 9416                   Pokemon Gold/Pokemon Silver      7.20
# 4199                             Super Mario Bros.      6.81
# 6937                         New Super Mario Bros.      6.50
# 10555                Pokemon Diamond/Pokemon Pearl      6.04
# 10621                  Pokemon Black/Pokemon White      5.65
# 10917                Pokemon Ruby/Pokemon Sapphire      5.38
# 3273                   Animal Crossing: Wild World      5.33
# 511    Brain Age 2: More Training in Minutes a Day      5.32
# 1847                      Monster Hunter Freedom 3      4.87

# %%
x6 = x1.iloc[:,[0,4]]
x6 = x6.sort_values(by=['Other_Sales'], axis=0, ascending=False)

x6 = x6[0:10]
x6
# Out:
#                                 Name  Other_Sales
# 14669  Grand Theft Auto: San Andreas        10.57
# 2908                      Wii Sports         8.46
# 14665                 Gran Turismo 4         7.53
# 3483              Grand Theft Auto V         4.14
# 12579                 Mario Kart Wii         3.31
# 3352               Wii Sports Resort         2.96
# 8213       Pro Evolution Soccer 2008         2.93
# 6937           New Super Mario Bros.         2.90
# 3014                        Wii Play         2.85
# 11137                     Nintendogs         2.75

# %%
xx2 = x2['Name']
xx3 = x3['Name']
xx4 = x4['Name']
xx5 = x5['Name']
xx6 = x6['Name']

# %%
x2 = x2.set_index("Name")
x3 = x3.set_index("Name")
x4 = x4.set_index("Name")
x5 = x5.set_index("Name")
x6 = x6.set_index("Name")

# %%
explode = [0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05]

# %%
plt.pie(x2,labels=xx2, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True)
plt.title('total' , fontsize=30)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """Entry point for launching an IPython kernel.
# Text(0.5, 1.0, 'total')

# %%
plt.pie(x3,labels=xx3, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True)
plt.title('NA_Sales' , fontsize=30)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """Entry point for launching an IPython kernel.
# Text(0.5, 1.0, 'NA_Sales')

# %%
plt.pie(x4,labels=xx4, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True)
plt.title('EU_Sales' , fontsize=30)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """Entry point for launching an IPython kernel.
# Text(0.5, 1.0, 'EU_Sales')

# %%
plt.pie(x5,labels=xx5, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True)
plt.title('JP_Sales' , fontsize=30)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """Entry point for launching an IPython kernel.
# Text(0.5, 1.0, 'JP_Sales')

# %%
plt.pie(x6,labels=xx6, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True)
plt.title('Other_Sales' , fontsize=30)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """Entry point for launching an IPython kernel.
# Text(0.5, 1.0, 'Other_Sales')

# %% [markdown]
# 총 판매량은 Wii Sports가 가장 높고 각 지역별로 NA_Sales,EU_Sales는 Wii Sports가 JP_Sales는 Pokemon가 Other_Sales는 Grand Theft Auto: San Andreas가 가장 높은 순위를 차지한걸 볼수있었다.
# 흥미로운 점은 유럽의 경우는 전체적인 판매량을 보면 액션게임류가 많이 제작되고 판매되었지만 정작 가장 인기있는 상품들은 스포츠류의 게임이 었다는것을 확인 할수 있다.
# 다시 말하자면 액션은 게임의 수 자체는 많지만 각각 하나의 판매량은 크게 높지는 않으니 이 지역들은 스포츠류의 게임을 판매한느것이 이득일 것이라 판단되며 일본은 롤플레잉이 강세이며 그외 지역은 액션이 상위권의 대부분을 차지하고있다.
# 게임 플랫폼은 플랫폼 종합을 기준으로 볼 경우 Nintendo 게임이 상위 판매게임의 대부분을 차지하고 있는것을 확인할수있었습니다.

# %% [markdown]
# 위의 자료들을 전체적으로 종합해보면 미국과 유럽 지역은 스포츠류 게임을 Nintendo 계열의 플랫폼을 통하여 판매하는것이 최대의 효과를 볼 수 있을것이며
# 일본의 경우는 롤플레잉 게임을 Nintendo 계열을 통하여 그 외 다른 지역은 액션게임을 PS플랫폼을 통하여 판매하는것이 가장 크게 이득이 남을거라 예측이 가능합니다.
#
# 마지막으로 제 개인적인 생각으로는 요즘 모바일게임 산업이 성장중이니 저희도 이 기회에 모바일게임 산업쪽으로 참여해보는것도 하나의 방법이라고 생각합니다.
